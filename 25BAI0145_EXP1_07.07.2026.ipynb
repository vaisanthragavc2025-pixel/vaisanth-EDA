# %% [markdown]
# <a href="https://colab.research.google.com/github/vaisanthragavc2025-pixel/vaisanth-EDA/blob/main/25BAI0145_EXP1_07.07.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.ROCK PAPER SCISSOR
import random

choices = ["rock", "paper", "scissors"]
user = input("Enter rock, paper, or scissors: ").lower()
comp = random.choice(choices)

print(f"Computer chose: {comp}")

if user not in choices:
    print("Invalid choice!")
elif user == comp:
    print("It's a tie!")
elif (user == "rock" and comp == "scissors") or \
     (user == "paper" and comp == "rock") or \
     (user == "scissors" and comp == "paper"):
    print("You win!")
else:
    print("Computer wins!")
# Out:
# Enter rock, paper, or scissors: rock
# Computer chose: scissors
# You win!

# %%
#2.STAR PROGRAM
n = 5

for i in range(n):
    print(" " * (n - i - 1) + "*" * (2 * i + 1))

for i in range(n - 2, -1, -1):
    print(" " * (n - i - 1) + "*" * (2 * i + 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
#3.FIBONACCHI
n = int(input("Enter number of terms: "))

a, b = 0, 1

for i in range(n):
    print(a)
    a, b = b, a + b
# Out:
# Enter number of terms: 3
# 0
# 1
# 1

# %%
#4.COUNTDOWN TIMER
n = int(input("Enter starting number: "))

for i in range(n, -1, -1):
    print(i)

print("Blast off!")
# Out:
# Enter starting number: 5
# 5
# 4
# 3
# 2
# 1
# 0
# Blast off!

# %%
#5.PALINDROME CHECKER
text = input("Enter a word: ").lower()

is_palindrome = True
length = len(text)

for i in range(length // 2):
    if text[i] != text[length - 1 - i]:
        is_palindrome = False
        break

if is_palindrome:
    print(f"{text} is a palindrome!")
else:
    print(f"{text} is not a palindrome.")
# Out:
# Enter a word: RACECAR
# racecar is a palindrome!

# %%
#6.BINARY SEARCH
def binary_search(arr, target):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            low = mid + 1
        else:
            high = mid - 1

    return -1

numbers = [2, 5, 8, 12, 16, 23, 38, 45, 56, 72]
target = int(input("Enter number to search: "))
result = binary_search(numbers, target)

if result != -1:
    print(f"Found {target} at index {result}")
else:
    print(f"{target} not found in the list")
# Out:
# Enter number to search: 12
# Found 12 at index 3

# %%
#7.NUMBER ANALYZER
def is_prime(num):
    if num < 2:
        return False
    for i in range(2, int(num ** 0.5) + 1):
        if num % i == 0:
            return False
    return True

n = int(input("Enter a number: "))

if n % 2 == 0:
    print(f"{n} is Even")
else:
    print(f"{n} is Odd")

if is_prime(n):
    print(f"{n} is Prime")
elif n > 1:
    print(f"{n} is Composite")
else:
    print(f"{n} is neither Prime nor Composite")

# %%
#8.LIST STATISTICS
numbers = [12, 45, 7, 23, 56, 9, 34]

total = 0
maximum = numbers[0]
minimum = numbers[0]

for num in numbers:
    total += num
    if num > maximum:
        maximum = num
    if num < minimum:
        minimum = num

average = total / len(numbers)

print(f"List: {numbers}")
print(f"Sum: {total}")
print(f"Average: {average:.2f}")
print(f"Maximum: {maximum}")
print(f"Minimum: {minimum}")
# Out:
# List: [12, 45, 7, 23, 56, 9, 34]
# Sum: 186
# Average: 26.57
# Maximum: 56
# Minimum: 7

# %%
#9.TEXT AND CASE ANALYZER
text = input("Enter a sentence: ")

upper_text = ""
lower_text = ""
reversed_text = ""
char_count = 0
vowel_count = 0
word_count = 1

for char in text:
    char_count += 1

    if char in "AEIOUaeiou":
        vowel_count += 1

    if char == " ":
        word_count += 1

    if char.isupper():
        lower_text += char.lower()
    else:
        lower_text += char.upper()

for i in range(len(text) - 1, -1, -1):
    reversed_text += text[i]

print(f"Original: {text}")
print(f"Swapped Case: {lower_text}")
print(f"Reversed: {reversed_text}")
print(f"Character Count: {char_count}")
print(f"Vowel Count: {vowel_count}")
print(f"Word Count: {word_count}")
# Out:
# Enter a sentence: vaathiverf
# Original: vaathiverf
# Swapped Case: VAATHIVERF
# Reversed: frevihtaav
# Character Count: 10
# Vowel Count: 4
# Word Count: 1

# %%
#10.NUMBER GUESSING GAME
import random

number = random.randint(1, 100)
attempts = 0

print("Guess the number between 1 and 100!")

while True:
    guess = int(input("Enter your guess: "))
    attempts += 1

    if guess < number:
        print("Too low!")
    elif guess > number:
        print("Too high!")
    else:
        print(f"Correct! You guessed it in {attempts} attempts.")
        break
# Out:
# Guess the number between 1 and 100!
# Enter your guess: 100
# Too high!
# Enter your guess: 50
# Too high!
# Enter your guess: 25
# Too high!
# Enter your guess: 12
# Too high!
# Enter your guess: 6
# Too low!
# Enter your guess: 7
# Too low!
# Enter your guess: 9
# Too low!
# Enter your guess: 10
# Correct! You guessed it in 8 attempts.
